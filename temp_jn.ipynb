# %%
import json

# %% [markdown]
# ## Vote Sample

# %%
with open(r'legiscan_data\US\2025-2026_119th_Congress\vote\1471158.json') as f:
    vote_json = json.load(f)

# %%
vote_json['roll_call']
# Out:
# {'roll_call_id': 1471158,
#  'bill_id': 1901818,
#  'date': '2025-01-03',
#  'desc': 'On Ordering the Previous Question RC# 3',
#  'yea': 216,
#  'nay': 210,
#  'nv': 0,
#  'absent': 8,
#  'total': 434,
#  'passed': 1,
#  'chamber': 'H',
#  'chamber_id': 114,
#  'votes': [{'people_id': 8955, 'vote_id': 2, 'vote_text': 'Nay'},
#   {'people_id': 8957, 'vote_id': 2, 'vote_text': 'Nay'},
#   {'people_id': 8963, 'vote_id': 2, 'vote_text': 'Nay'},
#   {'people_id': 8964, 'vote_id': 2, 'vote_text': 'Nay'},
#   {'people_id': 8965, 'vote_id': 2, 'vote_text': 'Nay'},
#   {'people_id': 8967, 'vote_id': 2, 'vote_text': 'Nay'},
#   {'people_id': 8972, 'vote_id': 2, 'vote_text': 'Nay'},
#   {'people_id': 8976, 'vote_id': 2, 'vote_text': 'Nay'},
#   {'people_id': 8983, 'vote_id': 2, 'vote_text': 'Nay'},
#   {'people_id': 8988, 'vote_id': 2, 'vote_text': 'Nay'},
#   {'people_id': 8989, 'vote_id': 2, 'vote_text': 'Nay'},
#   {'people_id': 8995, 'vote_id': 2, 'vote_text': 'Nay'},
# ...

# %% [markdown]
# ## People Sample

# %%
with open(r'legiscan_data\US\2025-2026_119th_Congress\people\14906.json') as f:
    person_json = json.load(f)

# %%
person_json['person']['bioguide_id']
# Out:
# 'P000605'

# %% [markdown]
# ## Bill Sample

# %%
with open(r'legiscan_data\US\2025-2026_119th_Congress\bill\SB5.json') as f:
    bill_json = json.load(f)

# %%
bill_json

# -- Vote Status Meanings --
#  4 = Passed
#  5 = Vetoed
#  6 = Failed
# Out:
# {'bill': {'bill_id': 1903351,
#   'change_hash': '753ce542f3e4fc69494dd82bc42f72c3',
#   'session_id': 2199,
#   'session': {'session_id': 2199,
#    'state_id': 52,
#    'year_start': 2025,
#    'year_end': 2026,
#    'prefile': 0,
#    'sine_die': 0,
#    'prior': 0,
#    'special': 0,
#    'session_tag': 'Regular Session',
#    'session_title': '2025-2026 Regular Session',
#    'session_name': '119th Congress'},
#   'url': 'https://legiscan.com/US/bill/SB5/2025',
#   'state_link': 'https://www.congress.gov/bill/119th-congress/senate-bill/5/all-info',
#   'completed': 1,
#   'status': 4,
#   'status_date': '2025-01-29',
#   'progress': [{'date': '2025-01-06', 'event': 1},
#    {'date': '2025-01-21', 'event': 2},
#    {'date': '2025-01-23', 'event': 3},
#    {'date': '2025-01-29', 'event': 4},
#    {'date': '2025-01-29', 'event': 8},
#    {'date': '2025-01-29', 'event': 4}],
#   'state': 'US',
#   'state_id': 52,
#   'bill_number': 'SB5',
#   'bill_type': 'B',
# ...

# %% [markdown]
# ## Five Calls Response
#
# 📝 Five Calls ID check:
#  - Scott Perry (Five Calls ID: P000605)
#   ✅ Found Scott Perry in DB with people_id 14906
#  - John Fetterman (Five Calls ID: F000479)
#   ✅ Found John Fetterman in DB with people_id 24549
#  - Dave McCormick (Five Calls ID: M001243)
#   ✅ Found Dave McCormick in DB with people_id 25926
